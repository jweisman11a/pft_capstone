# %%
# Import libraries
import psutil
import pandas as pd
import numpy as np
from fuzzywuzzy import process, fuzz
import glob
import time
from textdistance import levenshtein
import boto3

# import os
# import statistics
# import plotly.graph_objects as go
# from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
# init_notebook_mode(connected=False)
# from nltk.tokenize import sent_tokenize, word_tokenize
# import matplotlib.pyplot as plt
# import seaborn as sns
# from sklearn.preprocessing import MinMaxScaler
# import umap
# from sklearn.neighbors import NearestNeighbors
# from sklearn.cluster import DBSCAN

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load cleaned data

# %%
psutil.virtual_memory()
# Out:
# svmem(total=8461193216, available=3370409984, percent=60.2, used=5090783232, free=3370409984)

# %%
# Read in commentors
commentors = pd.read_csv('data/cleaned/comments.csv', usecols=['commentor'])

# %% [markdown]
# ### Resolve commentors suspected to be the same individual

# %%
# number of unique commentors
commentors.commentor.nunique()
# Out:
# 165718

# %%
# get an example of a potential single commentor under two different usernames
commentors[commentors.commentor.str.contains("All Eyez On Me")]['commentor'].unique()
# Out:
# array(['"All Eyez On Me" in theaters NOW!!!',
#        '"All Eyez On Me" in theaters june 16 2017'], dtype=object)

# %%
# get another example
commentors[commentors.commentor.str.contains("Native Americans")]['commentor'].unique()
# Out:
# array(['*********************************************************************************** The Native Americans are not r*dsk*ns. They are human beings like you and me. FTTR! - Fail To The Racists!',
#        '*********************************************************************************** The Native Americans are not r*dsk*ns. They are human beings like you and me. FTTR! - Fail To The Racists! ***********************************************************',
#        'The Native Americans are not r*dsk*ns. They are human beings like you and me. FTTR! - Fail To The Racists!',
#        '*********************************************************************** The Native Americans are not r*dsk*ns. They are human beings like you and me. FTTR! - Fail To The Racists! ***********************************************************************',
#        'The Native Americans are not r*dsk*ns. They are human beings. FTTR! - Fail To The Racists!',
#        'The Native Americans are not r*dsk*ns! They are human beings! FTTR! - Fail To The Racistskins!'],
#       dtype=object)

# %%
fuzz.partial_ratio('"All Eyez On Me" in theaters NOW!!!','"All Eyez On Me" in theaters june 16 2017')
# Out:
# 83

# %%
unique_commentors = pd.DataFrame(commentors.commentor.unique())
unique_commentors.columns = ['commentor']
unique_commentors = unique_commentors.sort_values(by=['commentor']).reset_index(drop=True)
df = unique_commentors[:1000]

# %%
# %%time

# Create df of unique commentor's usernames
unique_commentors = pd.DataFrame(commentors.commentor.unique())
unique_commentors.columns = ['commentor']
unique_commentors = unique_commentors.sort_values(by=['commentor']).reset_index(drop=True)

increment = 1000
for i in range(0,round(unique_commentors.shape[0]), increment):
    start_time = time.time()
    print(i)
    df = unique_commentors[i:i+increment]

    # Compare usernames to find potential split entities
    potential_matches = list()
    for name in df.commentor:
        if len(name) < 10:
            continue
        for other_name in df.commentor:
            if name != other_name and len(other_name) > 10:
                score = fuzz.partial_ratio(name, other_name)
                if score >= 83:
                    potential_matches.append([name,other_name,score])

    potential_matches_df = pd.DataFrame(potential_matches, columns=['username1','username2','score'])
    potential_matches_df.to_csv(f'tmp_entity_resolution/{i}.csv', header=False, index=False)
    print(time.time() - start_time)

# %%
# Read in resolved usernames
resolved_usernames_files = glob.glob('tmp_entity_resolution/*.csv')
data = list()

for filename in resolved_usernames_files:
    df = pd.read_csv(filename, names=['commentor1','commentor2','score'])
    data.append(df)

resolved_usernames = pd.concat(data, axis=0, ignore_index=True)
resolved_usernames.shape
# Out:
# (54628, 3)

# %%
# Calculate various ratios
resolved_usernames['ratio'] = resolved_usernames.apply(lambda x: fuzz.ratio(x.commentor1, x.commentor2), axis=1)
resolved_usernames['partial_token_set_ratio'] = resolved_usernames.apply(lambda x: fuzz.partial_token_set_ratio(x.commentor1, x.commentor2), axis=1)
resolved_usernames['token_sort_ratio'] = resolved_usernames.apply(lambda x: fuzz.token_sort_ratio(x.commentor1, x.commentor2), axis=1)
resolved_usernames['WRatio'] = resolved_usernames.apply(lambda x: fuzz.WRatio(x.commentor1, x.commentor2), axis=1)
resolved_usernames['avg_score'] = resolved_usernames[['score', 'ratio','partial_token_set_ratio','token_sort_ratio']].mean(axis=1)
high_confidence_matches = resolved_usernames[resolved_usernames.WRatio >= 88]
high_confidence_matches.to_csv('tmp_resolved_entities/high_confidence_matches.csv', header=True, index=False)

# %%
# example of a potential single commentor operating under different usernames 
high_confidence_matches[high_confidence_matches.commentor1 == 'joetoronto'].head()
# Out:
#        commentor1  \
# 53816  joetoronto
# 53817  joetoronto
# 53818  joetoronto
# 53819  joetoronto
# 53820  joetoronto
#
#                                                          commentor2  score  \
# 53816     joetoronto and billswillnevermove in a nacho cheese match    100
# 53817                          joetoronto has 50 plus names on here    100
# 53818       joetoronto has 50 plus names on here including Lawrence    100
# 53819         joetoronto has 50 plus names on here including ee00ee    100
# 53820  joetoronto has an unhealthy obsession with Mack and Trubisky    100
#
#        ratio  partial_token_set_ratio  token_sort_ratio  avg_score  WRatio
# 53816     30                      100                30       65.0      90
# 53817     43                      100                43       71.5      90
# 53818     31                      100                31       65.5      90
# 53819     32                      100                32       66.0      90
# 53820     29                      100                29       64.5      90

# %%
# Create mapping between duplicate name and resolved name
resolved_commentors = dict()
for i in range(0, len(high_confidence_matches)):
    commentor1 = high_confidence_matches['commentor1'].iloc[i]
    commentor2 = high_confidence_matches['commentor2'].iloc[i]
    if commentor2 not in resolved_commentors.keys():
        if commentor1 not in resolved_commentors.keys():
            resolved_commentors[commentor2] = commentor1

# %%
resolved_commentors
# Out:
# {'"All Eyez On Me" in theaters june 16 2017': '"All Eyez On Me" in theaters NOW!!!',
#  '1Cheesehead': '#1Cheesehead',
#  '#1redskins-fan': '#1RedskinsfanDC',
#  '( ͠° ل͜ ͡°)': '( ͠°ل͜ ͡°)',
#  '*********************************************************************************** The Native Americans are not r*dsk*ns. They are human beings like you and me. FTTR! - Fail To The Racists!': '*********************************************************************** The Native Americans are not r*dsk*ns. They are human beings like you and me. FTTR! - Fail To The Racists! ***********************************************************************',
#  '*********************************************************************************** The Native Americans are not r*dsk*ns. They are human beings like you and me. FTTR! - Fail To The Racists! ***********************************************************': '*********************************************************************** The Native Americans are not r*dsk*ns. They are human beings like you and me. FTTR! - Fail To The Racists! ***********************************************************************',
#  '.Vox Veritas.': '.Cox Veritas',
#  '0 Playoff Wins Since Re-entering the League': '0 Playoff Wins',
#  '100crystalclearravens': '100CrystalClearRavens',
#  '1265lombardiave': '1265LombardiAve',
#  '1265lombardiavenue': '1265LombardiAve',
#  '12isgreaterthan4': '12greaterthan4',
#  '12seahawks12': '12seahawks',
#  '12thmanjosh': '12thmanJosh',
#  '12thmanhawks': '12thmanchawk',
#  '13timechamps': '12timechamps',
#  '18n1isstillbetterthanyourteam': '18n1isStillBetterThanYourTeam',
#  '1969KansasCityChiefsSuperbowlChampions': '1969&2019KansasCityChiefsSuperBowlChampions',
#  '1969nflchampionskansascitychiefs': '1969nflchampions',
#  '1976SoulPatrol': '1976 Soul Patrol',
#  '1nationraidernation': '1NationRaiderNation',
#  '1ogica1voicesays': '1logicalvoicesays',
#  '1ogicalvoicesays': '1logicalvoicesays',
#  '1phillyphan': '1phillyPhan',
#  '2007toyotafjforsaletulsa': '2007toyotafjforsale',
#  '2017nfcn0rthchampiondetroitlions': '2016nfcnorthchampiondetroitlions',
#  '2017nfcnorthchampiondetroitlions': '2016nfcnorthchampiondetroitlions',
#  '209eaglesfan': '206eaglesfan',
#  '22yearsagotoday': '22 years ago today',
#  '24mountaincreeks': '24MountainCreeks',
#  '253seahawker': '253seahawk',
#  '3ringsandcounting': '27ringsandcounting',
#  '4ringsandcounting': '27ringsandcounting',
#  '2mannings1cup': '2Mannings1Cup',
#  '2wheels2many': '2Wheels2Many',
#  '2Blackaces81': '2blackaces',
#  '2manyidiots': '2manyidiotfans',
#  '2nd_stringer': '2nd_Stringer',
#  '2ndaryinsanity': '2ndary Insanity',
#  '2soweggroll': '2sloweggroll',
#  '3sweetness4': '34sweetness',
#  '4 SB Losses & 0 Championships ✓ᵛᵉʳᶦᶠᶦᵉᵈ': '4 Losses & 0 Championships ✓ᵛᵉʳᶦᶠᶦᵉᵈ',
#  '4 Super Bowl Losses and ZERO Championships in 50 years SKOLOLOLOL!!!': '4 Super Bowl Losses and 0 Championships in 50 years SKOLOLOLOL!!!',
#  '40thstreetblack': '40thStreetBlack',
#  '49erFaithful': "49'er Faithful",
#  '49ersFaithful': "49'er Faithful",
#  '49erdynasty': '49erDynasty',
#  '49erfanatic': '49erFanatic',
#  '49ersfaithful4life': '49erfaithful4life',
#  '49erfan4lifemauiwaikapu': '49erfan4life',
#  '49ersfan4life': '49erfan4life',
#  '49ersfan4life88': '49erfan4life',
#  '49ersforlife': '49erforlife',
#  '49ersfaithful89': '49ersFaithful80',
#  '49ersallday': '49ersalldaway',
#  '4d9erdynasty49': '4d9erdynasty',
#  '4d9erdynasty5': '4d9erdynasty',
#  'Da Gas Man 1': 'Da Gas Man',
#  'Dallassucks17': 'DallasSucks',
#  'Damien Thorne': 'Damien Thorn',
#  'Danny Anderson': 'Dan Anderson',
#  'Dayne Anderson': 'Dan Anderson',
#  'Dan Snyder is a Moron': 'Dan Snyder',
#  "Dan Snyder's Grundle": 'Dan Snyder',
#  'Daniella Smith': 'Daniel Smith',
#  'Dark Donnie1': 'Dark Donnie',
#  'DarthGator7': 'Darth Gator',
#  'Davie Ricky': 'Davey Ricky',
#  'David Jennings': 'David Benning',
#  'David Carter': 'David Carpenter',
#  'David Copperfield is a magician': 'David Copperfield is a Magician',
#  'David Harris': 'David Harnois',
#  'David Robinson': 'David Robbins',
#  'DawgPounderJ': 'DawgPounder',
#  'Dawgpounder': 'DawgPounder',
#  'Dawgpounder31': 'DawgPounder',
#  'Dawgpounder86': 'DawgPounder',
#  'Dawkinseffect': 'DawkinsEffect',
#  'Dayton Dave': 'DaytonDave',
#  'kcchiefs5983': 'kcchiefs58',
#  'kcchiefsfandave2013': 'kcchiefsfandave',
#  'kcraiderfan': 'kcraiderdan',
#  'keeppounding23': 'keepounding1234',
#  'keeppounding09': 'keeppounding',
#  'keeppounding1': 'keeppounding',
#  'keeppounding51': 'keeppounding',
#  'keithbranson1': 'keithbrandon',
#  'kenmasters34': 'kenmasters',
#  'kennypowders': 'kenny_powers',
#  'kerrdog2111': 'kerrdog211',
#  'ketchupaholic@yahoo.com': 'ketchupaholic',
#  'kevindunn5219': 'kevindunn21',
#  'kevinravens1': 'kevinravens',
#  'kevinthecomic1': 'kevinthecomic',
#  'kidpresentable': 'kid presentable',
#  'killcourtney': 'kilcourtney',
#  'kilgoretrout2': 'kilgoretrout10',
#  'kingbeason52': 'kingbeason420',
#  'kingfish2015': 'kingfish2013',
#  'kinggeorge96': 'kinggeorge116',
#  'kingthielenscourt': 'kingthielanscourt',
#  'kirkcousinsnewsletter': 'kirkcousins',
#  'kissmyrings': 'kissmy4rings',
#  'kisstheringsclowns': 'kisstherings',
#  'kristopherk': 'kristopher',
#  'l0glcalv0icesays': 'l0gicalv0icesays',
#  'ladybucsandsteelersnut': 'ladybucs&steelersnut',
#  'lancaster760': 'lancaster76',
#  'laraiders2016': 'laraider2015',
#  'larams4lyfe': 'larams4life',
#  'laramsfan4lifeisajoke': 'laramsfan4life',
#  'largetony86': 'largetony68',
#  'laserrocketarm31': 'laserrocketarm12',
#  'lateralus8201': 'lateralus82',
#  'lateralus982': 'lateralus82',
#  'leatherface2012isloosebutthole': 'leatherface2012',
#  'leatherface2o12': 'leatherface2012',
#  'leatherhead9': 'leatherhead41',
#  'leatherneck82': 'leatherneck',
#  'leatherneck_69': 'leatherneck',
#  'leftysmoke44': 'leftysmoke',
#  'legionodoom': 'legionoboom',
#  'legionofboom25': 'legionoboom',
#  'legionofboom88': 'legionoboom',
#  'lesbuckets71': 'lesbuckets',
#  'letsgobuffal04': 'letgobuffalo4',
#  'letsgobuffalo4': 'letgobuffalo4',
#  'letsgobuffalo2090': 'letsgobuff',
#  'letsgobuffalo25': 'letsgobuff',
#  'letsgobuffaloin2011': 'letsgobuff',
#  'letsgosjsharks': 'letsgosharks',
#  'lewisisthebestsincepb': 'lewisisthebestsincePBwelcomebackZac',
#  'lifelongfinfan': 'lifelongfan',
#  'lifetimefan63': 'lifetimefan',
#  'lightenupfrancis': 'lightenupfrances',
#  'lightningboltz2013': 'lightningboltz',
#  'lineblacker': 'linebacker2',
#  'lionshammer': 'lionhammer',
#  'lionking1971': 'lionking1071',
#  'lions2011champs': 'lions2010champs',
#  'lionsfan1102': 'lionsfan11',
#  'lionsfan1971': 'lionsfan11',
#  'lionsfan2011': 'lionsfan20',
#  'lionsfan2014': 'lionsfan20',
#  'lionsfan2086': 'lionsfan20',
#  'lionsfan415': 'lionsfan41',
#  'lionsfan6976': 'lionsfan69',
#  'lionsfan981': 'lionsfan81',
#  'lionsfan2828': 'lionsfan82',
#  'lionsfanatic620': 'lionsfanatic',
#  'lionsfanatic84': 'lionsfanatic',
#  'lionsfanforlifebornthatway': 'lionsfanforlife',
#  'lionsfansince87': 'lionsfansince1976',
#  'lionsnation': 'lionsnati0n',
#  'lionstigersbearsohmy': 'lionsntigersnbearsohmy',
#  'lioswinnextyear': 'lionswinnextyear',
#  'liquidmuse3': 'liquidmuse',
#  'literofcola': 'liter0fcola',
#  'littlekaps4': 'littlekaps',
#  'lloydalford': 'lloyd alford',
#  'lloydchristmas1': 'lloydchristmas',
#  'lloydchristmas23': 'lloydchristmas',
#  'logicalvoicescowboybrother': 'logialvoicescowboybrother',
#  'logicailvoicesays': 'logica1voicesays',
#  'logical1voicesays': 'logica1voicesays',
#  'logicallvoicesays': 'logica1voicesays',
#  'logicalvoiccsays': 'logica1voicesays',
#  'logicalvoicesay': 'logica1voicesays',
#  'logicalvoicesaye': 'logica1voicesays',
#  'logicalvoicesays': 'logica1voicesays',
#  'logicalvoicesays1': 'logica1voicesays',
#  'logicalvoicesayss': 'logica1voicesays',
#  'logicalvoicesayz': 'logica1voicesays',
#  'logicalvoiceseys': 'logica1voicesays',
#  'logicalvoicessay': 'logica1voicesays',
#  'logicalvoicessays': 'logica1voicesays',
#  'logicalvoicessayss': 'logica1voicesays',
#  'logicalvolcesays': 'logica1voicesays',
#  'logicalvoycesays': 'logica1voicesays',
#  'logicelvoicesays': 'logica1voicesays',
#  'logiclevoicesays': 'logica1voicesays',
#  'logicalvoicesssays': 'logicaillvoicesays',
#  'logicalthinkersays': 'logicalthinkersay',
#  'logicalvoicepftisanidiot': 'logicalvoicepft',
#  'londonfletcher59': 'londonfletcher',
#  'longball1419': 'longball11',
#  'longislandcowboysfan33': 'longislandcowboysfan',
#  'longsufferingbillsfans': 'longsufferingbillsfan',
#  'longtimefanhtr': 'longtimefan',
#  'longtymefan': 'longtimefan',
#  'lordhelmet25': 'lordhelmet23',
#  'lordstanley716': 'lordstanley65',
#  'lostsurfer101': 'lostsurfer100',
#  'louisstarks': 'louis starks',
#  'louisvillecardinals': 'louisville',
#  'louisvillepride': 'louisville',
#  'louisvilleslugger94': 'louisville',
#  'lowlifenebula1': 'lowlifenebula',
#  'loyallionsfan': 'loyallionfan',
#  'lpcustom73gmailcom': 'lpcustom73',
#  'lunchbox253': 'lunchbox53',
#  'luvthatdirtywatah': 'luvthatdirtywata',
#  'luvthatdirtywater1': 'luvthatdirtywata',
#  'mad scientist': 'maadscientist',
#  'majikbullet': 'majik_bullet_7',
#  'majormalphunktion': 'majmalphunktion',
#  'manningfan98': 'manningfan',
#  'manofsteel3': 'manofsteel2013',
#  'manonthemoon4': 'manonthemoon19',
#  'marcribaudo1965gmailcom': 'marcribaudo',
#  'marcussallen': 'marcus_allen',
#  'marcuswelby70': 'marcuswelby1',
#  'marinephinfan1': 'marinephinfan',
#  'markpugner43': 'markpugner',
#  'marshallfaulksboxoftissues': 'marshallfaulk',
#  'marshawnsgrillz': 'marshawnsgrill',
#  'martineast01': 'martineast',
#  'marylandelphiamouse': 'marylandelphia mouse',
#  'mastershake31': 'masstershake',
#  'masterblaster78': 'masterblaster',
#  'mastercaster': 'masterblaster',
#  'matthoover4': 'matthoover',
#  'mattyice211': 'mattyice11',
#  'maverick1100': 'maverick10',
#  'maverick4321': 'maverick43',
#  'maxinquaye7': 'maxinquaye',
#  'mccarthymtnb': 'mccarthymtn',
#  'mccourtyisland': 'mccourty1sland',
#  'mdeaglesfan410': 'mdeaglesfan',
#  'Delusional Jackass': 'Delusional',
#  'DelusionalInnerCityLiberalDemocratMillennial': 'Delusional',
#  'DennisJustice': 'Dennis Justice',
#  'Deplorable Ernie': 'Deplorable Ernesto',
#  'Deplorable ernie': 'Deplorable Ernesto',
#  'DesertEagle76': 'DesertEagle1776',
#  'Detroit Rocks City': 'Detroit Mock City',
#  'DevilsAdvocate': 'Devils Advocate',
#  'Dewey Axewound': 'Dewey Axewoond',
#  'Dial-A-Cliche.': 'Dial-A-Cliche',
#  'DiamondDave13': 'DiamondDave',
#  'Dilly Dilly': 'DillyDilly',
#  'Dirk. Diggler.': 'Dirk Diggler',
#  'Dirk.Diggler.': 'Dirk Diggler',
#  'DirkDiggler': 'Dirk Diggler',
#  'DirkDiggler69': 'Dirk Diggler',
#  'DirtyWaters': 'Dirty Waters',
#  'Dirty_Waters': 'Dirty Waters',
#  'DirtyBirds06': 'DirtyBird06',
#  'Display name (patriots123456) is a racist coward!!!': 'Display Name',
#  'DisplayName': 'Display Name',
#  'DocHolliday89': 'Doc Holliday',
#  'Dolphinatic': 'Dolphanatic',
#  'Dolphin Fan 51': 'Dolphin Fan',
#  'Dolphin Fan': 'DolphinFan',
#  'DolphinFanNY': 'DolphinFan',
#  'Dolphinfan4Ever': 'DolphinFan',
#  'Dolphinfanuk': 'DolphinFan',
#  'DonCorleone': 'Don Corleone',
#  'Donald Trump is a draft dodger who hates POWs and children': 'Donald Trump',
#  'Donald Trump is a draft dodger who hates brown people, POWs and children': 'Donald Trump',
#  'Donkey Kong!!': 'Donkey Kong!',
#  'DoubleNickel': 'Double Nickel',
#  'Dr. Hannibal Lector': 'Dr Hannibal Lector',
#  'Dracula in cleats': 'Dracula In Cleats',
#  'meccalambeaufield4': 'meccalambeaufield3',
#  'megatron81urcrazy': 'megatron81',
#  'megatronn81': 'megatron81',
#  'menofsteelx6': 'menofsteel',
#  'metalhead76': 'metalhead65',
#  'metalhead9652': 'metalhead65',
#  'metalman1320': 'metalman30',
#  'mgbleedsgreen': 'mgBleedsGreen',
#  'miamifan4life': 'miafan4life',
#  'miamifishfan': 'miafishfan',
#  'miamikillerdolphins': 'miami305killerdolphins',
#  'miamidolfan19': 'miamidolfan',
#  'miamifan2010': 'miamifan00',
#  'michaelpastro': 'michael castro',
#  'michaelf9123': 'michael89123',
#  'michaeldrewd': 'michaeldrew',
#  'michaeloptv1': 'michaeloptv',
#  'michiganman717': 'michiganman',
#  'michlight95': 'michlight1985',
#  'midnightgreen12': 'midnight green',
#  'midnightgreen85': 'midnight green',
#  'midnightgrn': 'midnight green',
#  'midnightmaurader': 'midnightmarauderii',
#  'midniterambler7': 'midnightrambler77',
#  'midwaymonster81': 'midwaymonster161',
#  'midwaymonster54': 'midwaymonster1985',
#  'mike mccarthy': 'mike mcCarthy',
#  'mikeinbrookline': 'mikebinrookline',
#  'mikebrownsux': 'mikebrownfaux',
#  'mikebrownsucks.com': 'mikebrownsucks',
#  'mikebrownsucks2019': 'mikebrownsucks',
#  'mikecheck619': 'mikecheck6',
#  'mikeflorioakasuperherolibbyagenda': 'mikeflorio',
#  'mikefloriodanceslikeagirl': 'mikeflorio',
#  'mikeflorioisadouche': 'mikeflorio',
#  'mikeflorioisadouchebag': 'mikeflorio',
#  'mikeflorioisaredskin': 'mikeflorio',
#  'mikeflorioismybitch': 'mikeflorio',
#  'mikeflorioisonkraftspayroll': 'mikeflorio',
#  'mikefloriosbabyd': 'mikeflorio',
#  'mikefloriosbastardson': 'mikeflorio',
#  'mikeflorioshusband': 'mikeflorio',
#  'mikefloriosimaginaryfriend': 'mikeflorio',
#  'mikefloriosucksballs': 'mikeflorio',
#  'mikefloriosucksbradysballs': 'mikeflorio',
#  'mikefloriosuxdixncox': 'mikeflorio',
#  'mikefloriothethird': 'mikeflorio',
#  'mike honcho': 'mikehoncho',
#  'mikehoncho79': 'mikehoncho',
#  'mikepbuffalo': 'mikeinbuffalo',
#  'mikelitoriss': 'mikelitoris1',
#  'mikethevike11': 'mikethevike',
#  'mikethevike28': 'mikethevike',
#  'mikethevike32': 'mikethevike',
#  'miketomlinssteelers10': 'miketomlin',
#  'milehighdonkeyshow': 'milehighdonkeys',
#  'milehighmagik7': 'milehighmagic7',
#  'milehighsalutebroncos': 'milehighsal',
#  'milleniummitch6': 'milleniummitch',
#  'millertime27': 'millertime20',
#  'millertime30': 'millertime20',
#  'ministerofdefense92': 'ministerofdefense',
#  'minnesconsin_ad': 'minnesconsin',
#  'mistakebythelake45': 'mistakebythelake',
#  'mistakeonthelake': 'mistakebythelake',
#  'mistakenny49': 'mistakenny',
#  'misterunderhill72': 'misterunderhill',
#  'mitchcumstein': 'mitch cumstein',
#  'mitchellc8728': 'mitchell8228',
#  'mitchellb75': 'mitchellb55',
#  'mitsuharumisawaxx9': 'mitsuharumisawax9',
#  'mmmpierogi is JoeTorontos20thProfile is joetoronto': 'mmmpierogi',
#  'mnnightowl2': 'mnnightowl',
#  'mnpackersfan': 'mnpackerfan20',
#  'mnsportsfan21': 'mnsportsfan',
#  'mnsportsfanatic85': 'mnsportsfan',
#  'mnvikesfan44': 'mnvikesfan',
#  'mnvikesfan78': 'mnvikesfan',
#  'mnvikingfan84': 'mnviking1fan',
#  'mnvikingsfan': 'mnviking1fan',
#  'moenthelawn82': 'moenthelawn',
#  'monoxidechild011': 'monoxidechild',
#  'monroesaintsfan': 'monroesaints',
#  'monster1321': 'monster1211',
#  'monstersmasher': 'monstermase',
#  'montrealraider is the spinless joetoronto...obviously!': 'montrealraider',
#  'mooncussersss': 'mooncussers',
#  'mooseknucklesammich': 'mooseknuckle',
#  'motorcitymadmen': 'motorcityM',
#  'mountaindont64': 'mountaindont',
#  'mountainman27': 'mountainman',
#  'mountainman5': 'mountainman',
#  'mountainman54': 'mountainman',
#  'mountainman777': 'mountainman',
#  'mountainman96': 'mountainman',
#  'mrbigchestbrown': 'mrbigchest',
#  'mrcommonsense23': 'mrcommonsense1',
#  'mrfloydpink123': 'mrfloydpink',
#  'mr.football': 'mrfootball',
#  'mrmojorisin': 'mrhojorisin',
#  'mrpresident50': 'mrpresident2',
#  'mrreferee53': 'mrreferee52',
#  'murlikoushik': 'murli koushik',
#  'murphyslaw80': 'murphyslaw40',
#  'musiccitymiracle2': 'musiccitymiracle',
#  'mustangbaby16': 'mustangbaby',
#  'my team has been improving for 63 years, currently we have one playoff win in 1991': 'my team has been improving for 62 years, currently we have one playoff win in 1991',
#  'my2cents277': 'my2cents27',
#  'mydixienormus': 'mydixieenormous',
#  'myfriendbobsacamanosays': 'myfriendbobsacamano',
#  'mythoughtsexactlyaye': 'mythoughts',
#  'myvickinabox14': 'myvickinabox',
#  'nagurski_T_form': 'nagurskiTform',
#  'namputhiri@yahoo.com': 'namputhiri',
#  'nastynati513': 'nastinati513',
#  'naturallawandselfownership': 'naturallaw',
#  'natureboy704': 'natureboy4',
#  'nbcsports420': 'nbcsports0',
#  'ncraiderfan25': 'ncraiderfan',
#  'ncsteeler86': 'ncsteeler83',
#  'ndvikingfan': 'ncvikingfan',
#  'neauxgeaux44': 'neauxgeaux',
#  'negadelphianinjersey': 'negadelphian',
#  'nepatsfan89': 'nepatsfan83',
#  'newwavedave9hotmailcom': 'newwavedave8hotmailcom',
#  'newyorkfootballgiants24': 'newyorkfootballgiants1080',
#  'nfceastisbeast': 'nfceastbeast',
#  'nfceastfan21': 'nfceastfan',
#  'nflanalyst03': 'nflanalyst',
#  'nflanalyst1': 'nflanalyst',
#  'nflanalyst19': 'nflanalyst',
#  'nflcombineresultsseo': 'nflcombineresults',
#  'nflcommissioner': 'nflcomissioner',
#  'nflfan1blog': 'nflfan12blog',
#  'nflfan4life21': 'nflfan4life',
#  'nfl_follies': 'nflfollies',
#  'ngatachancebal': 'ngatachance',
#  'nickjim316nickjim517': 'nickjim316',
#  'nighttrain916': 'nighttrain59',
#  'niners4life': 'niner4life8',
#  'niners4life826': 'niner4life8',
#  'ninerz4life': 'niner4life8',
#  'ninner4life': 'niner4life8',
#  'ninersallday49': 'ninerallday',
#  'ninerdynasty32': 'ninerdynasty',
#  'ninerempire7': 'ninerempire',
#  'ninerfaithful47': 'ninerfaithful',
#  'ninerfaithful75': 'ninerfaithful',
#  'ninerfaithful760': 'ninerfaithful',
#  'ninerfaithful84': 'ninerfaithful',
#  'ninerfaithful86': 'ninerfaithful',
#  'ninersfaithful86': 'ninerfaithful',
#  'ninerfan0497': 'ninerfan49',
#  'ninerfan4949': 'ninerfan49',
#  'ninerfan0850': 'ninerfan80',
#  'ninernation187': 'ninernation',
#  'ninernation47': 'ninernation',
#  'ninernation48': 'ninernation',
#  'ninernation49': 'ninernation',
#  'ninernation81': 'ninernation',
#  'ninernationnut': 'ninernation',
#  'ninernowiner': 'ninernowhiner',
#  'ninersfan75': 'ninersfan58',
#  'ninersfan82': 'ninersfan58',
#  'ninersfan86': 'ninersfan58',
#  'ninerssince84': 'ninersince81',
#  'nitschke066': 'nitschke66',
#  'njpackersfan': 'njpackerfan',
#  'njraidersfan': 'njraiderfan19',
#  'nobodybeatsthewiz30': 'nobodybeatstheriz',
#  'nofaceangler718': 'nofaceangler',
#  'nofoolsnodrool': 'nofoolnodroo1',
#  'nofunleague25': 'nofunleague',
#  'nofunleagueNFL': 'nofunleague',
#  'nofunleaguechildplease': 'nofunleague',
#  'nola_saints': 'nola_saint',
#  'nolasaint82': 'nolasaint25',
#  'nolawhodat9': 'nolawhodat',
#  'nopepper123': 'nopepper12',
#  'norcaldiscgolf1': 'norcaldiscgolf',
#  'norsehorse88': 'norsehorse',
#  'northernhorn': 'northerhorn',
#  'northernniner': 'northern49niner',
#  'northstarsmitty': 'northstars',
#  'northwoods1': 'northwoods',
#  'northwoodsv2': 'northwoods',
#  'northwoodsviking': 'northwoods',
#  'nosleeptilsb': 'nosleeptil',
#  'nostrocommonus': 'nostracommonus',
#  'notlisteninganymore': 'not listening anymore',
#  'nothingman20': 'nothingman',
#  'notoriousbuc': 'notorious_buc',
#  'notpftcommenter': 'notpftcommentator',
#  'notpftcommentor': 'notpftcommentator',
#  'nowhere_man': 'nowhereman',
#  'numba1minnysportsfan': 'numba1Minnesportsfan',
#  'DublinDemons': 'Dublin Demons',
#  'DynastyDriven77': 'DynastyDriven',
#  'Eagle_Fan34': 'Eagle Fan34',
#  'Eagles Fan in OC, MD': 'Eagles Fan',
#  'Eagles fan JJ': 'Eagles Fan',
#  'Eagles in 2015': 'Eagles in 2014',
#  'Eagles4life': 'Eagles4Life',
#  'EaglesLifer': 'Eagles4Life',
#  'EaglesFan05': 'EaglesFan01',
#  'EaglesFan91': 'EaglesFan01',
#  'Eaglesfan290': 'EaglesFan290',
#  'EaglesFan83': 'EaglesFan35',
#  'Eagles_Nest': 'EaglesNest',
#  'East of Eden': 'East Of Eden 6',
#  'Edward Monster': 'Edward Foster',
#  'El_Duderino': 'El Duderino',
#  'Emmitt Smith': 'Emmit Smith',
#  'EnoughAlready': 'Enough Already',
#  'Eric Anderson': 'Eric Andersen',
#  'Eric Chase.': 'Eric Chase Fox1470.com',
#  'Erik the Red': 'Eric the Red',
#  'Ernie Ernie': 'ErnieErnie',
#  'Espionage_Obama': 'Espionage_0bama',
#  'EverybodyGotsAIDS': 'EverybodyGotAIDS',
#  'nycheesehead420': 'nycheesehead',
#  'nyc_traffic': 'nyctraffic',
#  'nyfootballgiants': 'nyfootbalgiants',
#  'nygiants1090': 'nygiants1980',
#  'nygiantsfan92': 'nygiantsfan22',
#  'nyjallfingday': 'nyjalleffingday',
#  'nyjetsholdupsbtrophyin2012': 'nyjetsholdupsbtrophyin2010',
#  'nynbkfarsuperiorx': 'nynbkfarsuperior',
#  'oaklandraidersfan69': 'oaklandraiderfan',
#  'oaktownraider13': 'oaktownraider',
#  'oaktownraidrz': 'oaktownraider',
#  'oaktownrayder': 'oaktownraider',
#  'obamasucksmajorc0ck': 'obamasucks',
#  'objectivefbfan': 'objectivefan',
#  'objectivenflfan': 'objectivefan',
#  'odinvalhalla': 'odinofvalhalla',
#  'ohioraider22': 'ohioraider',
#  'ohiosteelerfan1980': 'ohiosteelerfan',
#  'ohiosteelersfan': 'ohiosteelerfan',
#  'oldassgoat1': 'oldassgoat',
#  'oldbrownsfan1': 'oldbrownsfan',
#  'oldmanbirdman': 'oldmanbirdfan',
#  'oldmanriver55': 'oldmanriver',
#  'oldschoolnflman': 'oldschoolfan',
#  'oldschoolnfl74': 'oldschoolnfl',
#  'omniscient48': 'omniscient',
#  'omniscientballer22': 'omniscient',
#  'oneinchpunchy': 'oneinchpunch',
#  'onepointtwentyonejiggawatts': 'onepointtwentyonegigawatt',
#  'onewinningdrive96': 'onewinningdrive',
#  'onlyconservativeopinionsallowedhere': 'onlyconservativeopinionsallowed',
#  'onthewarpath28': 'onthewarpath',
#  'orangeandblack31': 'orangandblack',
#  'orangeandblack67': 'orangandblack',
#  'orange and blue own the nfl': 'orange & blue own the NFL',
#  'orange and blue owns the NFL': 'orange & blue own the NFL',
#  'orangechrush': 'orange crush',
#  'orangecrush': 'orange crush',
#  'orangecrush1': 'orange crush',
#  'orangecrush15': 'orange crush',
#  'orangecrush21': 'orange crush',
#  'orangecrush24': 'orange crush',
#  'orangecrush47': 'orange crush',
#  'orangecrush53': 'orange crush',
#  'orangecrush67': 'orange crush',
#  'orangecrush78': 'orange crush',
#  'orangecrush92': 'orange crush',
#  'orangecrushd': 'orange crush',
#  'orangecrushd7': 'orange crush',
#  'orangecrushil': 'orange crush',
#  'orangecrushya': 'orange crush',
#  'orangeandbrown85': 'orangeandbrown19',
#  'orangecrush228': 'orangecrush1232',
#  'orangecrush823': 'orangecrush1232',
#  'orangecrushd13': 'orangecrush1232',
#  'orangecrush808': 'orangecrush5818',
#  'originalpsl': 'originalgsl',
#  'osiris33 (bandwagon fan since 2012)': 'osiris (bandwagon fan since 2012)',
#  'osiris33 (bandwagon since 2012)': 'osiris (bandwagon fan since 2012)',
#  'osiris33-and-beastmode5150-are-delusional-trolls': 'osiris33-and-beastmode5150-are-delusional-moron-trolls',
#  'ottograham14': 'ottograham',
#  'outerspace24': 'outerspace23',
#  'overratedselfpromoter': 'overatedselfpromoter',
#  'overobservant': 'overlyobservant',
#  'pack15forever1': 'pack15forever',
#  'packerfan4life': 'packafan4life',
#  'packfan4life': 'packafan4life',
#  'packattack04': 'packattack',
#  'packattack12': 'packattack',
#  'packattack13': 'packattack',
#  'packattack18': 'packattack',
#  'packattack40': 'packattack',
#  'packattack42': 'packattack',
#  'packattack71': 'packattack',
#  'packattack75': 'packattack',
#  'packattack79': 'packattack',
#  'packattack80': 'packattack',
#  'packattack91': 'packattack',
#  'packattack95': 'packattack',
#  'packattacked': 'packattack',
#  'packattackisback': 'packattack',
#  'packattack1987': 'packattack1967',
#  'packdaddy87': 'packdaddy85',
#  'packers4life': 'packer4life',
#  'packerbacker051653': 'packerbacker',
#  'packerbacker12': 'packerbacker',
#  'packerbacker247': 'packerbacker',
#  'packerbacker42': 'packerbacker',
#  'packerbacker51': 'packerbacker',
#  'packerbacker626': 'packerbacker',
#  'packerbacker65': 'packerbacker',
#  'packerbacker69': 'packerbacker',
#  'packerbacker73': 'packerbacker',
#  'packerbacker84': 'packerbacker',
#  'packerbacker86': 'packerbacker',
#  'packerbacker93': 'packerbacker',
#  'packerbackerg': 'packerbacker',
#  'packerbackernj': 'packerbacker',
#  'packerbackersince2k10': 'packerbacker',
#  'packerbackersince71': 'packerbacker',
#  'packerpacker': 'packerbacker',
#  'packersbacker': 'packerbacker',
#  'packerbacker1986': 'packerbacker1965',
#  'packerbacker1987': 'packerbacker1965',
#  'packerbacker2010': 'packerbacker2008',
#  'packerbacker2785': 'packerbacker2008',
#  'packerfan121': 'packerfan12',
#  'packerfan1268': 'packerfan12',
#  'packerfan12gb': 'packerfan12',
#  'packerfan36': 'packerfan33',
#  'packerfan66': 'packerfan46',
#  'packfan4ever': 'packerfan4ever',
#  'packersfan4life': 'packerfan4life1',
#  'packerfannbforlife': 'packerfanforlife',
#  'packfanforlife': 'packerfanforlife',
#  'packerfansarefatdrunkandstupid': 'packerfansarefat',
#  'packerfansrfat': 'packerfansarefat',
#  'packerguy85': 'packerguy59',
#  'packerhater28': 'packerhater',
#  'packerman1968': 'packerman126',
#  'packers2337': 'packers1337',
#  'packersfan04': 'packersfan',
#  'packersfan4everbaby': 'packersfan',
#  'packersfanjason': 'packersfan',
#  'packersrule52': 'packersrule12',
#  'packerssuckandsodoyou': 'packerssuck',
#  'packerssuckcheese': 'packerssuck',
#  'packerssuckmyditka': 'packerssuck',
#  'packerswin21': 'packerswin',
#  'packerswin96': 'packerswin',
#  'packrfan122152': 'packfan1252',
#  'packfannchitown': 'packfaninchitown',
#  'packfaninmn': 'packfaninminny',
#  'packfaninny52': 'packfaninny',
#  'packman1983': 'packman1958',
#  'pakmanjones': 'packmanjones',
#  'packsoldier69': 'packsoldier',
#  'packtopack20112012': 'packtopack',
#  'panchosmith': 'pancho smith',
#  'pantherdan89': 'pantherdan',
#  'pantherfan1970': 'pantherfan1967',
#  'pantherfan1986': 'pantherfan1967',
#  'pantherfan294': 'pantherfan2834',
#  'pantherfan4055': 'pantherfan40',
#  'pantherfan550': 'pantherfan40',
#  'pantherfan4life0210': 'pantherfan4life',
#  'pantherfan85': 'pantherfan55',
#  'pantherfan95': 'pantherfan55',
#  'pantherguy52': 'pantherguy',
#  'panthers4life34': 'panthers4life',
#  'panthers4life59': 'panthers4life',
#  'panthers4life78': 'panthers4life',
#  'panthersfan123459': 'panthersfan',
#  'panthersfan520': 'panthersfan',
#  'panthersfan83': 'panthersfan',
#  'panthersfan89': 'panthersfan',
#  'panthersfan95': 'panthersfan',
#  'panthersfanlos': 'panthersfan',
#  'parasolmonster': 'parasol monster',
#  'paredskinwarrior1985': 'paredskinwarrior',
#  'partylikeits1972': 'partylikeits1964',
#  'paschendale69': 'paschendale68',
#  'pastorinisflak': "pastorini'sflak",
#  'patpatriot7': 'pat patriot',
#  'patsfan1951': 'patfan1951',
#  'patrickwins': 'patrickowns',
#  'patriotsfan': 'patriot fan',
#  'patriotdynasty5': 'patriotdynasty',
#  'patriotsking': 'patriotking',
#  'patriots123': 'patriots12',
#  'patriots2120': 'patriots12',
#  'patriots420': 'patriots40',
#  'patriots5435': 'patriots55',
#  'patriotscheatingdynastylives': 'patriotscheat',
#  'patriotsfan54': 'patriotsfan51',
#  'patriotsrn1': 'patriotsr1',
#  'patriotsssss': 'patriotsss',
#  'patriotswin': 'patriotsw1n',
#  'patriotworld': 'patriotsworld',
#  'patriotway1': 'patriotway',
#  'patriotway12': 'patriotway',
#  'patriotwayrules': 'patriotway',
#  'patriotwayspygate': 'patriotway',
#  'patsarebetterthanyourteam': 'pats are better than your team',
#  'pats haters suck sucks': 'pats haters suck',
#  'pats suck, blow and cheat*': 'pats suck, blow and cheat',
#  'patsalltheway83': 'patsalltheway',
#  'patsaredone': 'patsardone',
#  'patscheat15': 'patscheat1',
#  'patzdominate': 'patsdominate',
#  'patsfan0414': 'patsfan0124',
#  'patsfan1234': 'patsfan0124',
#  'patsfan2112': 'patsfan112',
#  'patsfan1221': 'patsfan1213',
#  'patsfan1287': 'patsfan1275',
#  'patsfan3175': 'patsfan1275',
#  'patsfan3776': 'patsfan1776',
#  'patsfan1967': 'patsfan1960',
#  'patsfan2011': 'patsfan2001',
#  'patsfan4444': 'patsfan444',
#  'patsfancandy': 'patsfancanada',
#  'patsfanforevah': 'patsfanforeva',
#  'patsnation7': 'patsnation1',
#  'patsrbetterthanyourteam6': 'patsrbetter',
#  'patthepatriot666': 'patthepatriot',
#  'pauloverbey': 'pauloerbey',
#  'paultagliabue2': 'paultagliabue',
#  'paulwhiskey336': 'paulwhiskey',
#  'peytonneck18': 'paytonsneck18',
#  'peytonsneck18': 'paytonsneck18',
#  'perspective24': 'perspective',
#  'pervyharvin': 'pervy harvin',
#  'peskys_pole': 'peskyspole',
#  'petedutcherjr': 'petedutcher',
#  'peterGriffin': 'peter6riffin',
#  'peternorth1': 'peternorth',
#  'peterozelle01': 'peterozelle',
#  'petetheheat50': 'petethecheat',
#  'peytonshead': 'peytons5head',
#  'peytonsneck18isinlovewithrg3': 'peytonsneck',
#  'peytonsnecki8': 'peytonsneck',
#  'peytonsneckl8': 'peytonsneck',
#  'pftcommenter2': 'pftcommenter',
#  'pftcommenterguy': 'pftcommenter',
#  'pftcommentersuperb': 'pftcommenter',
#  'pftttcommenter': 'pftcommenter',
#  'pftpoetliksballz': 'pftpoetlicksballz',
#  'pftusername1': 'pftusername',
#  'phatbuddha57': 'phatbuddha',
#  'philaeagles31': 'philaeagles215',
#  'philiprivers619': 'philiprivers17',
#  'phillyeagle': 'philleagles',
#  'phillyeagles': 'philleagles',
#  'phillyeagles10': 'philleagles',
#  'phillyeagles22': 'philleagles',
#  'phillyeagles85': 'philleagles',
#  'philllyphanatic': 'philllyfanatic',
#  'phillyfanatic': 'philllyfanatic',
#  'phillypfanatic': 'philllyfanatic',
#  'phillyphan68': 'philllyphan83',
#  'phillyphan83': 'philllyphan83',
#  'phillyphan93': 'philllyphan83',
#  'phillyphann83': 'philllyphan83',
#  'phillyphannn83': 'philllyphan83',
#  'phillyiggles10': 'philly iggles',
#  'phillyphan1': 'philly-phan',
#  'phillyforlife': 'philly20forlife',
#  'phillyboston': 'philly2boston',
#  'phillybird85': 'phillybird',
#  'phillybirdgang1933': 'phillybird',
#  'phillybirds': 'phillybird',
#  'phillybirds25': 'phillybirds22',
#  'phillycheez': 'phillycheeez',
#  'phillyeagle212': 'phillyeagle1425',
#  'phillyeagles12345': 'phillyeagle1425',
#  'phillyeaglesfan29': 'phillyeaglefan',
#  'phillyeagles725': 'phillyeagles0715',
#  'philyeagles5': 'phillyeagles536',
#  'phillyfan04': 'phillyfan03',
#  'phillyfan20': 'phillyfan03',
#  'phillyfan34': 'phillyfan03',
#  'phillyfan63': 'phillyfan03',
#  'phillyfan21': 'phillyfan1212',
#  'phillyfan1978': 'phillyfan19',
#  'phillyfan41': 'phillyfan19',
#  'phillyfan97': 'phillyfan19',
#  'phillyphinsfan': 'phillyfinsfan',
#  'phillyfreak7': 'phillyfreak24',
#  'phillygirl1': 'phillygirl',
#  'philly-phan': 'phillyphan',
#  'phillyphan15': 'phillyphan',
#  'phillyphan54': 'phillyphan',
#  'phillyphan72': 'phillyphan',
#  'phillyphan75': 'phillyphan',
#  'phillyphan77': 'phillyphan',
#  'phillyphan99': 'phillyphan',
#  'phillyphanatic21': 'phillyphan',
#  'phillyphanatic29': 'phillyphan',
#  'phillyphanatic77': 'phillyphan',
#  'phillyphannnn83': 'phillyphan',
#  'phillyrockz': 'phillyrocks',
#  'phillysphinest': 'phillysfinest',
#  'phillysports25': 'phillysports1',
#  'phillysports7': 'phillysports1',
#  'phillysports77': 'phillysports1',
#  'phillysteaks': 'phillysteak24',
#  'phillysteve': 'phillysteel',
#  'philmccracken': 'philmacracken',
#  'phillyphinatic27': 'phinatic27',
#  'phinfan2006': 'phinfan2004',
#  'phinsfan1205': 'phinsfan10',
#  'phinsfan136': 'phinsfan13',
#  'phinsfanwife': 'phinsfan4life',
#  'phoenixsong17': 'phoenixsong117',
#  'phootballphanatic3000': 'phootballphanatic00',
#  'phxbroncophan': 'phxbroncofan',
#  'pigskinpete': 'pigskin pete',
#  'pigskindream233040461': 'pigskindream',
#  'pigskinnedytboy': 'pigskinnedwytboy',
#  'pigskinpimp68': 'pigskinpimp',
#  'pigskinytboi': 'pigskinwytboy',
#  'pigskinytboy': 'pigskinwytboy',
#  'pioliforprez': 'pioli_for_prez',
#  'piratefreedom': 'pirate freedom',
#  'pistol_pete': 'pistol7pete',
#  'pistolpetey': 'pistol7pete',
#  'pistol7pete': 'pistolpete',
#  'pistolpete31': 'pistolpete',
#  'pitsburHGH cheats': 'pitsburHGH Cheats',
#  'pittsburghsteelerz': 'pittsburghsteelergal',
#  'pksullivanmph': 'pksullivanmha',
#  'playmaker22': 'playmaker21',
#  'pmgfootball32': 'pmgfootball',
#  'pointnumberone': 'pointNumberOne',
#  'politicallyincorrect20': 'politicallyincorrect',
#  'pologroundsveteran': 'pologroundsvet',
#  'polomontanna1': 'polomontanna',
#  'pooflingingmonkey2': 'pooflingingmonkey',
#  'pooperscooper56': 'pooperscooper',
#  'poppinfresh64': 'poppinfresh',
#  'pozone6031gmailcom': 'pozone6031',
#  'preseasonchampions': 'preseasonchamp',
#  'preseasonchamps08': 'preseasonchamp',
#  'preventoffenseirkesme': 'preventoffense',
#  'primetime81': 'primetime17',
#  'primetime212': 'primetime2',
#  'primetime36': 'primetime6',
#  'primetime666': 'primetime6',
#  'productundefined.': 'productundefined',
#  'profantasyplyr': 'profantasyplayer',
#  'professorpigskin46': 'professorpigskin10',
#  'profootball13': 'profootball101',
#  'profootballgossip': 'profootballboss',
#  'profootballcaulk': 'profootballcalk',
#  'profootballtalk5': 'profootballcalk',
#  'profootballtalker': 'profootballcalk',
#  'profootballwalk': 'profootballcalk',
#  'profootballfan500': 'profootballfan',
#  'profootballfanatics11': 'profootballfan',
#  'profootballfansassociation': 'profootballfan',
#  'profootballpro': 'profootballpost',
#  'profootballsock': 'profootballrocks',
#  'profootballtruther': 'profootballtruth',
#  'progressiveshatethetruth2': 'progressiveshatethetruth',
#  'proudamerican123': 'proudamerican',
#  'proudbucsfan': 'proudbucfan',
#  'proudpapaof2': 'proudpapa2',
#  'purplepuzzyetrz': 'prplpuzzetrz',
#  'psubeerman21': 'psubeerman',
#  'psychoward86': 'psychoward',
#  'puckthafatriots****': 'puckthafatriots',
#  'puckthefatriots': 'puckthafatriots',
#  'puregenius47': 'puregenius',
#  'purplehayseuss': 'purple hay-seuss',
#  'purple haze harvin': 'purple haze',
#  'purplepeoplebeaters': 'purple people eaters',
#  'purplepeopleeaters123': 'purple people eaters',
#  'purple4life2': 'purple4life',
#  'purple4lyfe': 'purple4life',
#  'purplecitybirdgang52': 'purplecity_birdgang',
#  'purpledrank26': 'purpledork26',
#  'purple haze': 'purplehaze',
#  'purplehaze12': 'purplehaze',
#  'purplehaze28': 'purplehaze',
#  'purplehaze55335': 'purplehaze',
#  'purplehazedelaware': 'purplehaze',
#  'purplehelmet': 'purplehellmut',
#  'purplejesus28': 'purplejesus',
#  'purplejesusmvp': 'purplejesus',
#  'purplengolduntilimdeadandcold': 'purplengold',
#  'purplepassion1961': 'purplepassion1',
#  'purpleppleeaters': 'purpleppleater84',
#  'purplepride11': 'purplepride',
#  'purplepride26': 'purplepride',
#  'purplepride35': 'purplepride',
#  'purplepride67': 'purplepride',
#  'purplepride74': 'purplepride',
#  'purplepride75': 'purplepride',
#  'purplepride80': 'purplepride',
#  'purplepride84': 'purplepride',
#  'purplepridehasadownside': 'purplepride',
#  'purplepridepolysemy': 'purplepride',
#  'purplepriderunsdeep': 'purplepride',
#  'purplereign23': 'purplereign2',
#  'purplereign28': 'purplereign2',
#  'purplereign52': 'purplereign2',
#  'purplethunder98': 'purplethunder',
#  'pwillisbeast': 'pwillis52beasty',
#  'quickdraw85': 'quickdraw53',
#  'quotetheraven10': 'quotetheraven',
#  'quoththeraven': 'quotetheraven',
#  'r8idernation': 'r8dernation',
#  'raidernation4life': 'r8ernation4life',
#  'rabiddawg51': 'rabiddawg19',
#  'rageagainst7': 'rageagainst07',
#  'raider4life916': 'raider4life',
#  'raider4lifeweb': 'raider4life',
#  'raider4lyfe': 'raider4life',
#  'raiderlife1': 'raider4life',
#  'raiderlifer': 'raider4life',
#  'raiders4life': 'raider4life',
#  'raiders4life20': 'raider4life',
#  'raiderz4life': 'raider4life',
#  'raideralex7': 'raideralex',
#  'raideralex99': 'raideralex',
#  'raideralexander': 'raideralex',
#  'raiderbeater': 'raiderbeat',
#  'raiderbeer34': 'raiderbeer',
#  'raiderchris10': 'raiderchris',
#  'raiderchristian11': 'raiderchris',
#  'raiderdan69': 'raiderdan56',
#  'raiderdave22': 'raiderdave',
#  'raiderdave23': 'raiderdave',
#  'raiderdave31': 'raiderdave',
#  'raiderdave58': 'raiderdave',
#  'raiderdave66': 'raiderdave',
#  'raiderdavesblog': 'raiderdave',
#  'raiderdoug13': 'raiderdoug',
#  'raidereric44': 'raidereric',
#  'raiderfan123': 'raiderfan121',
#  'raiderfan2195': 'raiderfan121',
#  'raiderfan2412': 'raiderfan121',
#  'raiderfan121': 'raiderfan2',
#  'raiderfan24': 'raiderfan2',
#  'raiderfan29': 'raiderfan2',
#  'raiderfan2k4': 'raiderfan2',
#  'raidersfan24': 'raiderfan2',
#  'raidersfan26': 'raiderfan2',
#  'raidersfan401': 'raiderfan40',
#  'raiderman81': 'raiderfan81',
#  'raidersflyy': 'raiderflyy',
#  'raiderfourlife': 'raiderforlife1',
#  'raidersfolife': 'raiderforlife1',
#  'raidersfourlife': 'raiderforlife1',
#  'raiderjack91': 'raiderjack',
#  'raiderking1': 'raiderking',
#  'raiderking69': 'raiderking',
#  'raider love': 'raiderlove',
#  'raidermick3sb3rings': 'raidermick',
#  'raidermike in LA': 'raidermike',
#  'raidermike34': 'raidermike',
#  'raidernation15': 'raidernation1',
#  'raidernation210': 'raidernation1',
#  'raidernation32': 'raidernation1',
#  'raidernation34': 'raidernation1',
#  'raidernation3481': 'raidernation1',
#  'raidernation37': 'raidernation1',
#  'raidernation510': 'raidernation1',
#  'raidernation53': 'raidernation1',
#  'raidernation61': 'raidernation1',
#  'raidernation77': 'raidernation1',
#  'raidernation81': 'raidernation1',
#  'raidernation831': 'raidernation1',
#  'raidernation99': 'raidernation1',
#  'raidernationkc': 'raidernation1',
#  'raidernation7589': 'raidernation3739',
#  'raiderpower83': 'raiderpower',
#  'raiderrob0707': 'raiderrob07',
#  'raiders1976': 'raiders1960',
#  'raiders1980': 'raiders1960',
#  'raiders1983': 'raiders1982',
#  'raidersallday24': 'raidersallday',
#  'raidersallday323': 'raidersallday',
#  'raidersareterrible and joetoronto is a c0rk!': 'raidersareterrible',
#  'raidersrock666': 'raidersrock',
#  'raiderssuckballz': 'raiderssuckball',
#  'raidersteveo': 'raidersteve25',
#  'rainbowblizack': 'rainbow black',
#  'rajuncajun2863': 'rajuncajun28',
#  'ramblinwrecks': 'rambling wreck',
#  'Football Fan': 'FLFootballFan',
#  'FootballFan': 'FLFootballFan',
#  'Football_Fan': 'FLFootballFan',
#  'Footballfan': 'FLFootballFan',
#  'Footballfan1': 'FLFootballFan',
#  'Footballfanz': 'FLFootballFan',
#  'FalconsFan68': 'FalconsFan',
#  'Fan_of_Football': 'Fan_0f_Football',
#  'Fantasy Football Consultant': 'Fantasy Football',
#  'Fantasy Football Delivery Man': 'Fantasy Football',
#  'Fantasy Football Legend': 'Fantasy Football',
#  'Fantasy Football Rankings': 'Fantasy Football',
#  'FantasyFootballGod': 'Fantasy Football',
#  'Fargin_Icehole': 'Fargin Icehole',
#  'Fart Face Killah': 'Fart Face Killa',
#  'Favre2Harvin': 'Favre2Harv',
#  'Favre4Ever28': 'Favre4Ever',
#  'Ferrari_Driver': 'Ferrari Driver',
#  'FinFanatic80': 'FinFanatic',
#  'Finally, an article the Pats fans can comment on!': 'Finally, an article Pats fans can comment on!',
#  'Flex Jackson Jr.': 'Flex Jackson',
#  'Flipadelphia': 'Flip-adelphia',
#  'FlorioBorio': 'Florio Borio',
#  'FlorioHateMe': 'Florio Hates Me',
#  "Florios'Lawyer": "Florio's Lawyer",
#  'Florios-Lawyer': "Florio's Lawyer",
#  'Florioisanidiot': "Florio'sanidiot",
#  'Florioisanidiot1': "Florio'sanidiot",
#  'Floriosucks': 'FlorioSucks2',
#  'Floriosucksballs': 'FlorioSucksBall',
#  'Florioisadouchebag': 'Florioisadouche',
#  'Floriosadouchebag': 'Florioisadouche',
#  'Florioslovechild': 'FloriosLoveChild',
#  'Floriosqueens': 'FloriosQueens',
#  'FlyEaglesFly': 'Fly Eagles Fly',
#  'FlyEaglesFly82': 'FlyEaglesFly08',
#  'FlyEaglesFly85': 'FlyEaglesFly08',
#  'Flyingelvislogosucksbringbackpatpatriot': 'FlyingElvis',
#  'FootballFanatic11': 'Football Fanatic 21',
#  'FootballGod': 'Football God',
#  'Football Pro': 'Football Hero',
#  'Footballguy': 'Football guy',
#  'Footballismylife': 'Football is life',
#  'FootballisLife': 'Football4Life',
#  'FootballFanatik': 'FootballFanatic06',
#  'FootballPhreak': 'FootballFreak',
#  ...}

# %%
# Load entire comment dataset
commentors = pd.read_csv('data/cleaned/comments.csv', header=0)
commentors.head()
# Out:
#                                                                                                                  article_url  \
# 0                                                    https://profootballtalk.nbcsports.com/2020/10/25/week-7-2020-best-bets/
# 1                                                    https://profootballtalk.nbcsports.com/2020/10/25/week-7-2020-best-bets/
# 2  https://profootballtalk.nbcsports.com/2020/10/25/antonio-browns-civil-sexual-assault-trial-currently-is-set-for-december/
# 3  https://profootballtalk.nbcsports.com/2020/10/25/antonio-browns-civil-sexual-assault-trial-currently-is-set-for-december/
# 4  https://profootballtalk.nbcsports.com/2020/10/25/antonio-browns-civil-sexual-assault-trial-currently-is-set-for-december/
#
#    commentor  \
# 0     amaf21
# 1     amaf21
# 2  eagleswin
# 3   cobrala2
# 4  freakylj8
#
#                                                                                                                                                                                                            comment_body  \
# 0                                                                                                                                                                  \nthe best bet is the cowboys giving up 10 sacks.\n
# 1                                                                                                                                                                    \n1 strip sack for a safety down, 9 more to go.\n
# 2  \nTalent still trumps all in the NFL.  In between a lengthy suspension and a permanent suspension there was a 7 game window where he could play and didn’t the Bucs fall over themselves to take advantage of it.\n
# 3                                                                                                                                                                                        \nTom Brady wants this guy.\n
# 4                                                                                                                                                                         \nUse AB to let Godwin get healthy I guess\n
#
#               scrape_datetime comment_datetime_clean
# 0  2020-10-28 19:15:17.148123    2020-10-25 10:57:00
# 1  2020-10-28 19:15:17.148123    2020-10-25 13:20:00
# 2  2020-10-28 19:15:17.169123    2020-10-25 10:46:00
# 3  2020-10-28 19:15:17.169123    2020-10-25 10:54:00
# 4  2020-10-28 19:15:17.169123    2020-10-25 11:01:00

# %%
# Map resolved usernames
commentors['commentor_resolved'] = commentors['commentor'].map(resolved_commentors)
commentors['commentor_resolved'].fillna(commentors['commentor'], inplace=True)

# %%
# Inspect resolved commentors
# commentors.groupby(['commentor_resolved','commentor']).size().reset_index()
original_num_commentors = commentors['commentor'].nunique()
resolved_num_commentors = commentors['commentor_resolved'].nunique()
print(f'Original # Commentors: {original_num_commentors}')
print(f'Resolved # Commentors: {resolved_num_commentors}')
print(f'Diff: {original_num_commentors - resolved_num_commentors}')
# Out:
# Original # Commentors: 165718
# Resolved # Commentors: 161037
# Diff: 4681

# %%
commentors.to_csv('data/cleaned/comments_w_resolved_commentor.csv', header=True, index=False)

# %% [markdown]
# ### Upload updated dataset to S3

# %%
s3 = boto3.client('s3')
bucket = 'ml-guild-project-pft-comments'
s3.upload_file('data/cleaned/comments_w_resolved_commentor.csv', bucket, 'data/cleaned/comments_w_resolved_commentor.csv')

# %%
commentors = ''
